# %% [raw]
# # Import Libraries and Data

# %%
# Import libraries 
import pandas as pd 
import numpy as np 
import os

# %%
 # Path Variable 
path = r'C:\Users\jmiel\JENNY_STUFF\MY_DOCS\CareerFoundry\Instacart Basket Analysis'

# Import customer dataframe 
df_cust = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'customers.csv'), index_col = False)

# %% [markdown]
# # Data Wrangling for df_cust

# %%
# View data that was imported 
df_cust.head(20)
# Out:
#     user_id First Name    Surnam  Gender           STATE  Age date_joined  \
# 0     26711    Deborah  Esquivel  Female        Missouri   48    1/1/2017
# 1     33890   Patricia      Hart  Female      New Mexico   36    1/1/2017
# 2     65803    Kenneth    Farley    Male           Idaho   35    1/1/2017
# 3    125935   Michelle     Hicks  Female            Iowa   40    1/1/2017
# 4    130797        Ann   Gilmore  Female        Maryland   26    1/1/2017
# 5    133128    Cynthia     Noble  Female        Kentucky   43    1/1/2017
# 6    152052      Chris    Walton    Male         Montana   20    1/1/2017
# 7    168851     Joseph   Hickman    Male  South Carolina   30    1/1/2017
# 8     69965     Jeremy      Vang    Male           Texas   47    1/1/2017
# 9     82820      Shawn     Chung    Male        Virginia   26    1/1/2017
# 10    26441     Gloria  Stafford  Female          Nevada   19    1/1/2017
# 11    33835      Roger     Casey    Male        Nebraska   45    1/1/2017
# ...

# %% [markdown]
# After glancing over the column names, there are some formatting / spelling issues (some letters are capitalzed while others are not, some contain "_" while others don't

# %%
# View data types within dataframe 
df_cust.dtypes
# Out:
# user_id          int64
# First Name      object
# Surnam          object
# Gender          object
# STATE           object
# Age              int64
# date_joined     object
# n_dependants     int64
# fam_status      object
# income           int64
# dtype: object

# %%
# View data shape 
df_cust.shape
# Out:
# (206209, 10)

# %%
# Rename columns 
df_cust.rename(columns = {'First Name' : 'first_name'}, inplace = True)
df_cust.rename(columns = {'Surnam' : 'surname'}, inplace = True)
df_cust.rename(columns = {'Gender' : 'gender'}, inplace = True)
df_cust.rename(columns = {'STATE' : 'state'}, inplace = True)
df_cust.rename(columns = {'Age' : 'age'}, inplace = True)
df_cust.rename(columns = {'n_dependants' : 'number_of_dependants'}, inplace = True)
df_cust.rename(columns = {'fam_status' : 'marital_status'}, inplace = True)

# %%
# Check to see formatting of new columns 
df_cust.head()
# Out:
#    user_id first_name   surname  gender       state  age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    number_of_dependants marital_status  income
# 0                     3        married  165665
# 1                     0         single   59285
# 2                     2        married   99568
# 3                     0         single   42049
# 4                     1        married   40374

# %% [markdown]
# Columns are now in correct format

# %% [markdown]
# # Data Quality and Consistency Checks

# %%
# View Descriptive Statistics 
df_cust.describe()
# Out:
#              user_id            age  number_of_dependants         income
# count  206209.000000  206209.000000         206209.000000  206209.000000
# mean   103105.000000      49.501646              1.499823   94632.852548
# std     59527.555167      18.480962              1.118433   42473.786988
# min         1.000000      18.000000              0.000000   25903.000000
# 25%     51553.000000      33.000000              0.000000   59874.000000
# 50%    103105.000000      49.000000              1.000000   93547.000000
# 75%    154657.000000      66.000000              3.000000  124244.000000
# max    206209.000000      81.000000              3.000000  593901.000000

# %%
# Check for mixed data types 
for col in df_cust.columns.tolist():
    weird = (df_cust[[col]].map(type) != df_cust[[col]].iloc[0].apply(type)).any(axis = 1)
    if len (df_cust[weird]) > 0:
        print(col)
# Out:
# first_name

# %%
# Change first_name column datatype to string 
df_cust['first_name'] = df_cust['first_name'].astype('str')

# %%
# Change user_id column datatype to string 
df_cust['user_id'] = df_cust['user_id'].astype('str')

# %%
# Check to ensure that output worked
for col in df_cust.columns.tolist():
    weird = (df_cust[[col]].map(type) != df_cust[[col]].iloc[0].apply(type)).any(axis = 1)
    if len (df_cust[weird]) > 0:
        print(col)

# %%
# Check datatype 
df_cust.dtypes
# Out:
# user_id                 object
# first_name              object
# surname                 object
# gender                  object
# state                   object
# age                      int64
# date_joined             object
# number_of_dependants     int64
# marital_status          object
# income                   int64
# dtype: object

# %%
# Check descriptive statistics 
df_cust.describe()
# Out:
#                  age  number_of_dependants         income
# count  206209.000000         206209.000000  206209.000000
# mean       49.501646              1.499823   94632.852548
# std        18.480962              1.118433   42473.786988
# min        18.000000              0.000000   25903.000000
# 25%        33.000000              0.000000   59874.000000
# 50%        49.000000              1.000000   93547.000000
# 75%        66.000000              3.000000  124244.000000
# max        81.000000              3.000000  593901.000000

# %%
# Find missing values 
df_cust.isnull().sum()
# Out:
# user_id                 0
# first_name              0
# surname                 0
# gender                  0
# state                   0
# age                     0
# date_joined             0
# number_of_dependants    0
# marital_status          0
# income                  0
# dtype: int64

# %% [markdown]
# There are no missing values that need to be addressed

# %%
# Find full duplicates 
df_cust_dups = df_cust[df_cust.duplicated()]

# %%
df_cust_dups
# Out:
# Empty DataFrame
# Columns: [user_id, first_name, surname, gender, state, age, date_joined, number_of_dependants, marital_status, income]
# Index: []

# %% [markdown]
# There are no duplicates found

# %% [markdown]
# # Combine customer data with prepared Instacart data

# %%
# Import ords_prods_merge_aggregated dataframe 
ords_prods = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merge_aggregated.pkl'))

# %%
# Varify the data output is the same as previous task 
ords_prods.shape
# Out:
# (32404859, 24)

# %%
# Check the shape of df_cust 
df_cust.shape
# Out:
# (206209, 10)

# %%
# remove _merge column in ords_prods as this is no longer needed 
ords_prods = ords_prods.drop('_merge', axis=1)

# %%
# View the columns to determine the common column
ords_prods.head()
# Out:
#    order_id user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329       1             1                   2                  8
# 1   2539329       1             1                   2                  8
# 2   2539329       1             1                   2                  8
# 3   2539329       1             1                   2                  8
# 4   2539329       1             1                   2                  8
#
#    days_since_prior_order  first_order  product_id  add_to_cart_order  \
# 0                     NaN         True         196                  1
# 1                     NaN         True       14084                  2
# 2                     NaN         True       12427                  3
# 3                     NaN         True       26088                  4
# 4                     NaN         True       26405                  5
#
#    reordered  ... prices    price_range_loc    busiest_days  \
# ...

# %%
# View df_cust to determine common column 
df_cust.head()
# Out:
#   user_id first_name   surname  gender       state  age date_joined  \
# 0   26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1   33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2   65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3  125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4  130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    number_of_dependants marital_status  income
# 0                     3        married  165665
# 1                     0         single   59285
# 2                     2        married   99568
# 3                     0         single   42049
# 4                     1        married   40374

# %% [markdown]
# The common key includes the user_id column. This is the common identifier that will be used to merge the dataframes

# %%
ords_prods.dtypes['user_id']
# Out:
# dtype('int64')

# %%
df_cust.dtypes['user_id']
# Out:
# dtype('O')

# %% [markdown]
# After comparing the data types in both dataframes, it appears as though the user_id have differing datatypes
# which will need to be corrected prior to merging.

# %%
# change ords_prods user_id column to string 
ords_prods['user_id'] = ords_prods['user_id'].astype('str')

# %%
# Check to ensure the datatype has changed 
ords_prods.dtypes['user_id']
# Out:
# dtype('O')

# %% [markdown]
# Now datatypes match.

# %%
# merge df_cust on ords_prods via user_id with inner join 
customer_ords_prods_merge = ords_prods.merge(df_cust, on = ['user_id'], indicator = True)

# %%
customer_ords_prods_merge.head()
# Out:
#    order_id user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329       1             1                   2                  8
# 1   2539329       1             1                   2                  8
# 2   2539329       1             1                   2                  8
# 3   2539329       1             1                   2                  8
# 4   2539329       1             1                   2                  8
#
#    days_since_prior_order  first_order  product_id  add_to_cart_order  \
# 0                     NaN         True         196                  1
# 1                     NaN         True       14084                  2
# 2                     NaN         True       12427                  3
# 3                     NaN         True       26088                  4
# 4                     NaN         True       26405                  5
#
#    reordered  ... first_name  surname  gender    state age date_joined  \
# ...

# %%
# Check shape of merged data 
customer_ords_prods_merge.shape
# Out:
# (32404859, 33)

# %%
# inner join frequency check
customer_ords_prods_merge['_merge'].value_counts()
# Out:
# _merge
# both          32404859
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
# check datatypes in merged dataframe 
customer_ords_prods_merge.dtypes
# Out:
# order_id                     int64
# user_id                     object
# order_number                 int64
# orders_day_of_week           int64
# order_hour_of_day            int64
# days_since_prior_order     float64
# first_order                   bool
# product_id                   int64
# add_to_cart_order            int64
# reordered                    int64
# product_name                object
# aisle_id                     int64
# department_id                int64
# prices                     float64
# price_range_loc             object
# busiest_days                object
# busiest_period_of_day       object
# max_order                    int64
# loyalty_flag                object
# average_spent              float64
# spent_flag                  object
# customer_frequency         float64
# frequency_flag              object
# first_name                  object
# surname                     object
# gender                      object
# state                       object
# ...

# %% [markdown]
# order_id column should be changed to a string

# %%
customer_ords_prods_merge['order_id'] = customer_ords_prods_merge['order_id'].astype('str')

# %%
customer_ords_prods_merge.dtypes['order_id']
# Out:
# dtype('O')

# %% [markdown]
# # Export Merged Dataframe

# %%
customer_ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'customer_ords_prods_merge.pkl'))
